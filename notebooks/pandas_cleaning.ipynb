# %%
# Importing dependencies
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read data file and inspect dataset
file_path = os.path.join('data', 'Amazon Sale Report.csv')
amazon_sales = pd.read_csv(file_path)

print(amazon_sales.columns, "\n")
display(amazon_sales.head())
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')
# C:\Users\husse\AppData\Local\Temp\ipykernel_4708\3517283731.py:3: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   amazon_sales = pd.read_csv(file_path)
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# 0            Set  ...      INR  647.62       MUMBAI  MAHARASHTRA
# 1          kurta  ...      INR  406.00    BENGALURU    KARNATAKA
# 2          kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  Western Dress  ...      INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4            Top  ...      INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# # Data Munging

# %% [markdown]
# We'll start by normalizing column names, dtypes, and values

# %%
# Normalize column names and inspect info
amazon_sales.columns = (amazon_sales.columns.str.strip()
                        .str.replace(r'[-\s]', '_', regex=True)
                        .str.lower())
amazon_sales.rename(columns={'qty': 'quantity', 'fulfilment': 'fulfillment'}, inplace=True)
amazon_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   order_id            128975 non-null  object
#  2   date                128975 non-null  object
#  3   status              128975 non-null  object
#  4   fulfillment         128975 non-null  object
#  5   sales_channel       128975 non-null  object
#  6   ship_service_level  128975 non-null  object
#  7   style               128975 non-null  object
#  8   sku                 128975 non-null  object
#  9   category            128975 non-null  object
#  10  size                128975 non-null  object
#  11  asin                128975 non-null  object
#  12  courier_status      122103 non-null  object
#  13  quantity            128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  amount              121180 non-null  float64
#  16  ship_city           128942 non-null  object
#  17  ship_state          128942 non-null  object
#  18  ship_postal_code    128942 non-null  float64
#  19  ship_country        128942 non-null  object
#  20  promotion_ids       79822 non-null   object
#  21  b2b                 128975 non-null  bool
#  22  fulfilled_by        39277 non-null   object
#  23  unnamed:_22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB

# %%
# Drop unnamed column and convert date types
amazon_sales.drop(columns='unnamed:_22', inplace=True)
amazon_sales['date'] = pd.to_datetime(
    amazon_sales['date'], 
    format='%m-%d-%y'
)

categorical_columns = [
    'status', 'fulfillment', 'sales_channel', 'ship_service_level', 
    'category', 'size', 'courier_status', 'currency', 'ship_state',
    'ship_country', 'fulfilled_by'
]

string_columns = [
    'order_id', 'style', 'sku', 'asin', 'ship_city', 'promotion_ids',
    'ship_postal_code'
]


amazon_sales[categorical_columns] = amazon_sales[categorical_columns].astype('category')
amazon_sales[string_columns] = amazon_sales[string_columns].astype('string')

amazon_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   order_id            128975 non-null  string
#  2   date                128975 non-null  datetime64[ns]
#  3   status              128975 non-null  category
#  4   fulfillment         128975 non-null  category
#  5   sales_channel       128975 non-null  category
#  6   ship_service_level  128975 non-null  category
#  7   style               128975 non-null  string
#  8   sku                 128975 non-null  string
#  9   category            128975 non-null  category
#  10  size                128975 non-null  category
#  11  asin                128975 non-null  string
#  12  courier_status      122103 non-null  category
#  13  quantity            128975 non-null  int64
#  14  currency            121180 non-null  category
#  15  amount              121180 non-null  float64
#  16  ship_city           128942 non-null  string
#  17  ship_state          128942 non-null  category
#  18  ship_postal_code    128942 non-null  string
#  19  ship_country        128942 non-null  category
#  20  promotion_ids       79822 non-null   string
#  21  b2b                 128975 non-null  bool
#  22  fulfilled_by        39277 non-null   category
# dtypes: bool(1), category(11), datetime64[ns](1), float64(1), int64(2), string(7)
# memory usage: 12.3 MB

# %%
# Normalize values for categorical and string columns.
uppercase_strings = ['asin', 'style', 'size', 'sku', 'currency', 'ship_country']
lowercase_strings = [col for col in (categorical_columns + string_columns) 
                                 if col not in uppercase_strings]

amazon_sales[uppercase_strings] = (
    amazon_sales[uppercase_strings]
    .apply(lambda x: x.str.strip().str.upper())
)

amazon_sales[lowercase_strings] = (
    amazon_sales[lowercase_strings]
    .apply(lambda x: x.str.strip().str.lower())
)

display(amazon_sales[uppercase_strings].head())

display(amazon_sales[lowercase_strings].head())
# Out:
#          asin    style size              sku currency ship_country
# 0  B09KXVBD7Z   SET389    S   SET389-KR-NP-S      INR           IN
# 1  B09K3WFS32  JNE3781  3XL  JNE3781-KR-XXXL      INR           IN
# 2  B07WV4JV4D  JNE3371   XL    JNE3371-KR-XL      INR           IN
# 3  B099NRCT7B    J0341    L       J0341-DR-L      INR           IN
# 4  B098714BZP  JNE3671  3XL  JNE3671-TU-XXXL      INR           IN
#                          status fulfillment sales_channel ship_service_level  \
# 0                     cancelled    merchant     amazon.in           standard
# 1  shipped - delivered to buyer    merchant     amazon.in           standard
# 2                       shipped      amazon     amazon.in          expedited
# 3                     cancelled    merchant     amazon.in           standard
# 4                       shipped      amazon     amazon.in          expedited
#
#         category courier_status   ship_state fulfilled_by  \
# 0            set            NaN  maharashtra    easy ship
# 1          kurta        shipped    karnataka    easy ship
# 2          kurta        shipped  maharashtra          NaN
# 3  western dress            NaN   puducherry    easy ship
# 4            top        shipped   tamil nadu          NaN
#
#               order_id    ship_city  \
# 0  405-8078784-5731545       mumbai
# 1  171-9198151-1101146    bengaluru
# 2  404-0687676-7273146  navi mumbai
# 3  403-9615377-8133951   puducherry
# 4  407-1069790-7240320      chennai
#
#                                        promotion_ids ship_postal_code
# 0                                               <NA>         400081.0
# 1  amazon plcc free-financing universal merchant ...         560085.0
# 2       in core free shipping 2015/04/08 23-48-5-108         410210.0
# 3                                               <NA>         605008.0
# 4                                               <NA>         600073.0

# %%
# Check for duplicates and missing values
print(f"Number of duplicate rows: {amazon_sales.duplicated().sum()} \n")
print(f"Number of duplicate indicies: {amazon_sales.shape[0] - amazon_sales['index'].nunique()} \n")
print(f"Number of duplicate orders ids: {amazon_sales['order_id'].duplicated().sum()} \n")
print(f"Number of null entries by column:\n{amazon_sales.isna().sum()}")
# Out:
# Number of duplicate rows: 0
#
# Number of duplicate indicies: 0
#
# Number of duplicate orders ids: 8597
#
# Number of null entries by column:
# index                     0
# order_id                  0
# date                      0
# status                    0
# fulfillment               0
# sales_channel             0
# ship_service_level        0
# style                     0
# sku                       0
# category                  0
# size                      0
# asin                      0
# courier_status         6872
# quantity                  0
# currency               7795
# amount                 7795
# ship_city                33
# ship_state               33
# ship_postal_code         33
# ship_country             33
# promotion_ids         49153
# b2b                       0
# fulfilled_by          89698
# dtype: int64

# %% [markdown]
# We will address null values later in the SQL section. Let's start with duplicates. Looks like they are multiple parts of same order.

# %%
# Inspect duplicate order ids
amazon_sales[amazon_sales['order_id'].duplicated(keep=False)].sort_values('order_id')
# Out:
#        index             order_id       date                        status  \
# 78939  78939  171-0012693-2893106 2022-05-07                     cancelled
# 78938  78938  171-0012693-2893106 2022-05-07                     cancelled
# 91476  91476  171-0014231-7760344 2022-06-29                       pending
# 91475  91475  171-0014231-7760344 2022-06-29                       pending
# 24515  24515  171-0015435-1981904 2022-04-16                       shipped
# ...      ...                  ...        ...                           ...
# 74748  74748  408-9929975-2118741 2022-05-11  shipped - delivered to buyer
# 36052  36052  408-9951521-7399501 2022-04-09                       shipped
# 36053  36053  408-9951521-7399501 2022-04-09                       shipped
# 61445  61445  408-9954515-8573127 2022-05-22  shipped - delivered to buyer
# 61444  61444  408-9954515-8573127 2022-05-22  shipped - delivered to buyer
#
#       fulfillment sales_channel ship_service_level    style  \
# 78939    merchant     amazon.in           standard    NW015
# 78938    merchant     amazon.in           standard    NW030
# 91476      amazon     amazon.in          expedited    J0224
# 91475      amazon     amazon.in          expedited   SET342
# 24515      amazon     amazon.in          expedited  JNE3611
# ...           ...           ...                ...      ...
# 74748    merchant     amazon.in           standard   SET408
# 36052      amazon     amazon.in          expedited    J0338
# 36053      amazon     amazon.in          expedited    J0335
# 61445    merchant     amazon.in           standard   SET356
# 61444    merchant     amazon.in           standard   SET356
#
#                      sku       category  ... quantity currency   amount  \
# 78939      NW015-TP-PJ-S            set  ...        0      INR   477.14
# 78938      NW030-TP-PJ-S            set  ...        0      INR   538.10
# 91476       J0224-SKD-XS            set  ...        1      INR  1364.00
# 91475  SET342-KR-NP-N-XS            set  ...        1      INR   850.00
# 24515       JNE3611-KR-L          kurta  ...        1      INR   459.00
# ...                  ...            ...  ...      ...      ...      ...
# 74748  SET408-KR-NP-XXXL            set  ...        1      INR   499.00
# 36052         J0338-DR-M  western dress  ...        1      INR   744.00
# 36053         J0335-DR-M  western dress  ...        1      INR   807.00
# 61445   SET356-KR-NP-XXL            set  ...        1      INR   999.00
# 61444     SET356-KR-NP-M            set  ...        1      INR   999.00
#
#               ship_city         ship_state  ship_postal_code ship_country  \
# 78939    sri ganganagar          rajasthan          335001.0           IN
# 78938    sri ganganagar          rajasthan          335001.0           IN
# 91476         ahmedabad            gujarat          380015.0           IN
# 91475         ahmedabad            gujarat          380015.0           IN
# 24515  pimpri chinchwad        maharashtra          412101.0           IN
# ...                 ...                ...               ...          ...
# 74748        port blair  andaman & nicobar          744101.0           IN
# 36052      secunderabad          telangana          500017.0           IN
# 36053      secunderabad          telangana          500017.0           IN
# 61445            shimla   himachal pradesh          171005.0           IN
# 61444            shimla   himachal pradesh          171005.0           IN
#
#                                            promotion_ids    b2b fulfilled_by
# 78939                                               <NA>  False    easy ship
# 78938                                               <NA>  False    easy ship
# 91476                                               <NA>  False          NaN
# 91475                                               <NA>  False          NaN
# 24515       in core free shipping 2015/04/08 23-48-5-108  False          NaN
# ...                                                  ...    ...          ...
# 74748  amazon plcc free-financing universal merchant ...  False    easy ship
# 36052       in core free shipping 2015/04/08 23-48-5-108  False          NaN
# 36053       in core free shipping 2015/04/08 23-48-5-108  False          NaN
# 61445  amazon plcc free-financing universal merchant ...  False    easy ship
# 61444  amazon plcc free-financing universal merchant ...  False    easy ship
#
# [15443 rows x 23 columns]

# %% [markdown]
# To screen for true duplicates, we'll look for orders with same id, item asin, and date

# %%
# Inspect true duplicates
amazon_sales[amazon_sales.duplicated(subset=['order_id', 'asin', 'date'], keep=False)]
# Out:
#        index             order_id       date     status fulfillment  \
# 30660  30660  406-0372545-6086735 2022-04-12  cancelled      amazon
# 30661  30661  406-0372545-6086735 2022-04-12  cancelled      amazon
# 41291  41291  408-0373839-4433120 2022-04-05  cancelled      amazon
# 41292  41292  408-0373839-4433120 2022-04-05  cancelled      amazon
# 52330  52330  407-8364731-6449117 2022-05-29    shipped      amazon
# 52333  52333  407-8364731-6449117 2022-05-29    shipped      amazon
# 79844  79844  171-9628368-5329958 2022-05-07  cancelled      amazon
# 79845  79845  171-9628368-5329958 2022-05-07  cancelled      amazon
# 85790  85790  171-3249942-2207542 2022-05-03    shipped      amazon
# 85791  85791  171-3249942-2207542 2022-05-03    shipped      amazon
# 86418  86418  405-8669298-3850736 2022-05-03    shipped      amazon
# 86419  86419  405-8669298-3850736 2022-05-03    shipped      amazon
# 98954  98954  407-4853873-4978725 2022-06-22    shipped      amazon
# 98955  98955  407-4853873-4978725 2022-06-22    shipped      amazon
#
#       sales_channel ship_service_level    style              sku category  \
# 30660     amazon.in          expedited   SET197   SET197-KR-NP-L      set
# 30661     amazon.in          expedited   SET197   SET197-KR-NP-L      set
# 41291     amazon.in          expedited  JNE3501     JNE3501-KR-M    kurta
# 41292     amazon.in          expedited  JNE3501     JNE3501-KR-M    kurta
# 52330     amazon.in          expedited  JNE3769     JNE3769-KR-L    kurta
# 52333     amazon.in          expedited  JNE3769     JNE3769-KR-L    kurta
# 79844     amazon.in          expedited    J0329       J0329-KR-L    kurta
# 79845     amazon.in          expedited    J0329       J0329-KR-L    kurta
# 85790     amazon.in          expedited   SET323  SET323-KR-NP-XL      set
# 85791     amazon.in          expedited   SET323  SET323-KR-NP-XL      set
# 86418     amazon.in          expedited  MEN5025  MEN5025-KR-XXXL    kurta
# 86419     amazon.in          expedited  MEN5025  MEN5025-KR-XXXL    kurta
# 98954     amazon.in          expedited    J0230      J0230-SKD-M      set
# 98955     amazon.in          expedited    J0230      J0230-SKD-M      set
#
#        ... quantity currency  amount  ship_city     ship_state  \
# 30660  ...        0      NaN     NaN   siliguri    west bengal
# 30661  ...        0      NaN     NaN   siliguri    west bengal
# 41291  ...        0      NaN     NaN  bengaluru      karnataka
# 41292  ...        0      NaN     NaN  bengaluru      karnataka
# 52330  ...        0      NaN     NaN      theni     tamil nadu
# 52333  ...        1      INR   487.0      theni     tamil nadu
# 79844  ...        0      NaN     NaN  ernakulam         kerala
# 79845  ...        0      NaN     NaN  ernakulam         kerala
# 85790  ...        1      INR   939.0       pune    maharashtra
# 85791  ...        1      INR   939.0       pune    maharashtra
# 86418  ...        1      INR   533.0  ghaziabad  uttar pradesh
# 86419  ...        1      INR   533.0  ghaziabad  uttar pradesh
# 98954  ...        1      INR  1163.0   zirakpur         punjab
# 98955  ...        1      INR  1163.0   zirakpur         punjab
#
#        ship_postal_code ship_country  \
# 30660          734008.0           IN
# 30661          734008.0           IN
# 41291          560072.0           IN
# 41292          560072.0           IN
# 52330          625579.0           IN
# 52333          625579.0           IN
# 79844          682017.0           IN
# 79845          682017.0           IN
# 85790          411057.0           IN
# 85791          411057.0           IN
# 86418          201010.0           IN
# 86419          201010.0           IN
# 98954          140603.0           IN
# 98955          140603.0           IN
#
#                                       promotion_ids    b2b fulfilled_by
# 30660                                          <NA>  False          NaN
# 30661                                          <NA>  False          NaN
# 41291                                          <NA>  False          NaN
# 41292                                          <NA>  False          NaN
# 52330  in core free shipping 2015/04/08 23-48-5-108  False          NaN
# 52333  in core free shipping 2015/04/08 23-48-5-108  False          NaN
# 79844                                          <NA>  False          NaN
# 79845                                          <NA>  False          NaN
# 85790  in core free shipping 2015/04/08 23-48-5-108  False          NaN
# 85791  in core free shipping 2015/04/08 23-48-5-108  False          NaN
# 86418  in core free shipping 2015/04/08 23-48-5-108  False          NaN
# 86419  in core free shipping 2015/04/08 23-48-5-108  False          NaN
# 98954  in core free shipping 2015/04/08 23-48-5-108  False          NaN
# 98955  in core free shipping 2015/04/08 23-48-5-108  False          NaN
#
# [14 rows x 23 columns]

# %% [markdown]
# Not bad, only 7 true duplicates. Let's drop keeping last since one entry is missing amount info in first duplicate

# %%
# Drop duplicates
amazon_sales = amazon_sales.drop_duplicates(subset=['order_id', 'asin', 'date'], keep='last')
print(amazon_sales.shape[0])
# Out:
# 128968

# %% [markdown]
# ## Categorical Columns

# %%
# Inspect unique and null values per col
cat_stats = pd.DataFrame({
    'Unique Values': [amazon_sales[col].nunique() for col in categorical_columns],
    'Null Values': [amazon_sales[col].isna().sum() for col in categorical_columns],
}, index=categorical_columns)

display(cat_stats)
# Out:
#                     Unique Values  Null Values
# status                         13            0
# fulfillment                     2            0
# sales_channel                   2            0
# ship_service_level              2            0
# category                        9            0
# size                           11            0
# courier_status                  3         6872
# currency                        1         7791
# ship_state                     47           33
# ship_country                    1           33
# fulfilled_by                    1        89691

# %% [markdown]
# - Currency null values most likely can be filled with INR, but I'll double check against amount and item price info in SQL.
# - Having both status and courier status might be redundant.
# - Fulfilled by is ...?
#
# Let's inspect distributions

# %%
# Print unique value counts for categorical columns
for col in categorical_columns:
    print(amazon_sales[col].value_counts(), end="\n\n")
# Out:
# status
# shipped                          77800
# shipped - delivered to buyer     28769
# cancelled                        18329
# shipped - returned to seller      1953
# shipped - picked up                973
# pending                            658
# pending - waiting for pick up      281
# shipped - returning to seller      145
# shipped - out for delivery          35
# shipped - rejected by buyer         11
# shipping                             8
# shipped - lost in transit            5
# shipped - damaged                    1
# Name: count, dtype: int64
#
# fulfillment
# amazon      89691
# merchant    39277
# Name: count, dtype: int64
#
# sales_channel
# amazon.in     128844
# non-amazon       124
# Name: count, dtype: int64
#
# ship_service_level
# expedited    88608
# standard     40360
# Name: count, dtype: int64
#
# category
# set              50281
# kurta            49873
# western dress    15500
# top              10622
# ethnic dress      1159
# blouse             926
# bottom             440
# saree              164
# dupatta              3
# Name: count, dtype: int64
#
# size
# M       22709
# L       22129
# XL      20875
# XXL     18096
# S       17090
# 3XL     14815
# XS      11161
# 6XL       738
# 5XL       550
# 4XL       427
# FREE      378
# Name: count, dtype: int64
#
# courier_status
# shipped      109484
# unshipped      6681
# cancelled      5931
# Name: count, dtype: int64
#
# currency
# INR    121177
# Name: count, dtype: int64
#
# ship_state
# maharashtra               22259
# karnataka                 17325
# tamil nadu                11482
# telangana                 11330
# uttar pradesh             10637
# delhi                      6967
# kerala                     6584
# west bengal                5962
# andhra pradesh             5430
# gujarat                    4489
# haryana                    4415
# rajasthan                  2711
# madhya pradesh             2529
# odisha                     2136
# bihar                      2114
# punjab                     1916
# assam                      1663
# uttarakhand                1553
# jharkhand                  1456
# goa                        1137
# chhattisgarh                909
# himachal pradesh            788
# jammu & kashmir             702
# puducherry                  350
# chandigarh                  333
# manipur                     316
# andaman & nicobar           257
# meghalaya                   207
# sikkim                      205
# nagaland                    185
# tripura                     151
# arunachal pradesh           146
# new delhi                    81
# mizoram                      76
# dadra and nagar              70
# ladakh                       43
# lakshadweep                   4
# rajshthan                     3
# orissa                        3
# nl                            2
# rj                            2
# rajsthan                      2
# punjab/mohali/zirakpur        1
# pb                            1
# apo                           1
# ar                            1
# pondicherry                   1
# Name: count, dtype: int64
#
# ship_country
# IN    128935
# Name: count, dtype: int64
#
# fulfilled_by
# easy ship    39277
# Name: count, dtype: int64

# %% [markdown]
# - 128942/128975 have india as shipping country. We can fill in for the missing 33.
# - fulfilled_by and fulfillment both mark orders handled by easy ship. There are 39277 of them. We'll reconcile info and drop one of them

# %%
# Fill missing shipping country values. Reconcile fulfillment columns and drop one of them.
amazon_sales['ship_country'] = amazon_sales['ship_country'].fillna("IN")
amazon_sales['fulfillment'] = amazon_sales['fulfillment'].replace({'merchant': 'easy ship'})
amazon_sales.drop(columns='fulfilled_by', inplace=True)

print(amazon_sales['fulfillment'].value_counts())
print(amazon_sales['ship_country'].isna().sum())
# Out:
# fulfillment
# amazon       89691
# easy ship    39277
# Name: count, dtype: int64
# 0

# %% [markdown]
# Next up, we have only 3 dupatta and 164 saree items in the dataset. These categories are not standardized, we'll reassign as ethnic dress for consistency.

# %%
# Relabel categories for better consistency
amazon_sales.loc[
    (amazon_sales['category']=='dupatta') |
    (amazon_sales['category']=='saree')
    , 'category'] ='ethnic dress'

amazon_sales['category'].value_counts()
# Out:
# category
# set              50281
# kurta            49873
# western dress    15500
# top              10622
# ethnic dress      1326
# blouse             926
# bottom             440
# Name: count, dtype: int64

# %% [markdown]
# We're left with status/courier_status and ship state. We'll again try to reconcile the two columns.

# %%
# Inspect status vs courier status.
print(amazon_sales.groupby('status')['courier_status'].value_counts())
# Out:
# status                         courier_status
# cancelled                      cancelled          5837
#                                unshipped          5631
# pending                        unshipped           646
#                                shipped              10
#                                cancelled             2
# pending - waiting for pick up  unshipped           281
# shipped                        shipped           77593
#                                unshipped           115
#                                cancelled            92
# shipped - damaged              shipped               1
# shipped - delivered to buyer   shipped           28761
# shipped - lost in transit      shipped               5
# shipped - out for delivery     shipped              35
# shipped - picked up            shipped             973
# shipped - rejected by buyer    shipped              11
# shipped - returned to seller   shipped            1950
# shipped - returning to seller  shipped             145
# shipping                       unshipped             8
# Name: count, dtype: int64

# %% [markdown]
# Since transportation follows order processing, courier status is more up to date than status. Also looks like orders with cancelled
# status have 50/50 unshipped/cancelled courier status, meaning the terms were used interchangebly. So we make the simplifying assumption:
#
# - unshipped --> cancelled

# %%
# Simplify status values and reconcile with courier status
amazon_sales.loc[
    (amazon_sales['courier_status'] == 'unshipped') |
    (amazon_sales['courier_status'] == 'cancelled'),
'status'] = 'cancelled'

amazon_sales.loc[
    (amazon_sales['courier_status'] == 'shipped') &
    (amazon_sales['status'] == 'pending'),
'status'] = 'shipped'

print(amazon_sales.groupby('status')['courier_status'].value_counts())
print(f"\n{amazon_sales['status'].value_counts()}")
# Out:
# status                         courier_status
# cancelled                      unshipped          6681
#                                cancelled          5931
# shipped                        shipped           77603
# shipped - damaged              shipped               1
# shipped - delivered to buyer   shipped           28761
# shipped - lost in transit      shipped               5
# shipped - out for delivery     shipped              35
# shipped - picked up            shipped             973
# shipped - rejected by buyer    shipped              11
# shipped - returned to seller   shipped            1950
# shipped - returning to seller  shipped             145
# Name: count, dtype: int64
#
# status
# shipped                          77603
# shipped - delivered to buyer     28769
# cancelled                        19473
# shipped - returned to seller      1953
# shipped - picked up                973
# shipped - returning to seller      145
# shipped - out for delivery          35
# shipped - rejected by buyer         11
# shipped - lost in transit            5
# shipped - damaged                    1
# Name: count, dtype: int64

# %% [markdown]
# Considering ambiguity in cancelled shipment status, we won't be able to meaningfully distinguish between orders cancelled before shipment and orders we had to ship back for cost analysis. Instead, let's focus on analyzing consumer choices vis a vie cancellation. For this reason, I'll combine different categories as cancelled

# %%
# Combine status as cancelled or returned. Drop statuses with 0 value count
combine_status = {
    "shipped - returned to seller": "cancelled",
    "shipped - returning to seller": "cancelled",
    "shipped - rejected by buyer": "cancelled",
    "shipped - lost in transit": "cancelled",
    "shipped - damaged": "cancelled"
}
amazon_sales['status'] = amazon_sales['status'].replace(combine_status)
amazon_sales['status'] = amazon_sales['status'].replace({'cancelled': 'cancelled or returned'})

# All of these orders had updates in courier_status and were not updated in status. We are left with 0 order count for each. 
status_to_drop = ['pending', 'pending - waiting for pick up', 'shipping']
amazon_sales = amazon_sales[~amazon_sales['status'].isin(status_to_drop)]

print(amazon_sales['status'].value_counts())
print(amazon_sales.shape[0])
# Out:
# status
# shipped                         77603
# shipped - delivered to buyer    28769
# cancelled or returned           21588
# shipped - picked up               973
# shipped - out for delivery         35
# Name: count, dtype: int64
# 128968

# %% [markdown]
# Looks good. Let's drop courier status

# %%
# Drop courier_status
amazon_sales.drop(columns='courier_status', inplace=True)
display(amazon_sales.head())
# Out:
#    index             order_id       date                        status  \
# 0      0  405-8078784-5731545 2022-04-30         cancelled or returned
# 1      1  171-9198151-1101146 2022-04-30  shipped - delivered to buyer
# 2      2  404-0687676-7273146 2022-04-30                       shipped
# 3      3  403-9615377-8133951 2022-04-30         cancelled or returned
# 4      4  407-1069790-7240320 2022-04-30                       shipped
#
#   fulfillment sales_channel ship_service_level    style              sku  \
# 0   easy ship     amazon.in           standard   SET389   SET389-KR-NP-S
# 1   easy ship     amazon.in           standard  JNE3781  JNE3781-KR-XXXL
# 2      amazon     amazon.in          expedited  JNE3371    JNE3371-KR-XL
# 3   easy ship     amazon.in           standard    J0341       J0341-DR-L
# 4      amazon     amazon.in          expedited  JNE3671  JNE3671-TU-XXXL
#
#         category  ...        asin quantity  currency  amount    ship_city  \
# 0            set  ...  B09KXVBD7Z        0       INR  647.62       mumbai
# 1          kurta  ...  B09K3WFS32        1       INR  406.00    bengaluru
# 2          kurta  ...  B07WV4JV4D        1       INR  329.00  navi mumbai
# 3  western dress  ...  B099NRCT7B        0       INR  753.33   puducherry
# 4            top  ...  B098714BZP        1       INR  574.00      chennai
#
#     ship_state ship_postal_code ship_country  \
# 0  maharashtra         400081.0           IN
# 1    karnataka         560085.0           IN
# 2  maharashtra         410210.0           IN
# 3   puducherry         605008.0           IN
# 4   tamil nadu         600073.0           IN
#
#                                        promotion_ids    b2b
# 0                                               <NA>  False
# 1  amazon plcc free-financing universal merchant ...  False
# 2       in core free shipping 2015/04/08 23-48-5-108   True
# 3                                               <NA>  False
# 4                                               <NA>  False
#
# [5 rows x 21 columns]

# %% [markdown]
# Next, ship state. Many of the values are territories, so let's account for both

# %%
# Find incorrectly labeled states/territories
states_territories = '''Andhra Pradesh, Arunachal Pradesh, Assam, Bihar, Chhattisgarh, Goa, Gujarat, Haryana, 
Himachal Pradesh, Jharkhand, Karnataka, Kerala, Madhya Pradesh, Maharashtra, Manipur, Meghalaya, 
Mizoram, Nagaland, Odisha, Punjab, Rajasthan, Sikkim, Tamil Nadu, Telangana, Tripura, Uttar Pradesh, 
Uttarakhand, West Bengal, Andaman and Nicobar Islands, Chandigarh, Dadra and Nagar Haveli and Daman and Diu, 
Delhi, Jammu and Kashmir, Ladakh, Lakshadweep, Puducherry'''
states_territories = sorted(states_territories.replace('\n', '').lower().split(', '))
print(states_territories)
print(len(states_territories))
amazon_sales = amazon_sales.rename(columns={'ship_state': 'ship_state_or_territory'})

incorrect_states_labels = (amazon_sales[
    ~amazon_sales['ship_state_or_territory']
    .isin(states_territories)]['ship_state_or_territory']
.unique())
print(f"\n Incorrectly labeled states/territories:\n {incorrect_states_labels}")
# Out:
# ['andaman and nicobar islands', 'andhra pradesh', 'arunachal pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra and nagar haveli and daman and diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal pradesh', 'jammu and kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil nadu', 'telangana', 'tripura', 'uttar pradesh', 'uttarakhand', 'west bengal']
# 36
#
#  Incorrectly labeled states/territories:
#  ['jammu & kashmir' 'dadra and nagar' nan 'andaman & nicobar' 'rajshthan'
#  'nl' 'new delhi' 'punjab/mohali/zirakpur' 'rj' 'orissa' 'pb' 'apo' 'ar'
#  'pondicherry' 'rajsthan']

# %%
# Update values using a predictive model
update = {
    "jammu & kashmir": "jammu and kashmir",
    "dadra and nagar": "dadra and nagar haveli and daman and diu",
    "andaman & nicobar": "andaman and nicobar islands",
    "rajshthan": "rajasthan",
    "nl": "nagaland",
    "new delhi": "delhi",
    "punjab/mohali/zirakpur": "punjab",
    "rj": "rajasthan",
    "orissa": "odisha",
    "pb": "punjab",
    "apo": "unknown",
    "ar": "arunachal pradesh",
    "pondicherry": "puducherry",
    "rajsthan": "rajasthan"
}
amazon_sales['ship_state_or_territory'] = amazon_sales['ship_state_or_territory'].replace(update)

# Fill na values and the one address with "apo" as unknown.
amazon_sales[['ship_state_or_territory', 'ship_city', 'ship_postal_code']] = (
    amazon_sales[['ship_state_or_territory', 'ship_city', 'ship_postal_code']]
    .fillna('unknown')
)

print(amazon_sales['ship_state_or_territory'].isna().sum())
print(amazon_sales['ship_state_or_territory'].nunique())
print(sorted(amazon_sales['ship_state_or_territory'].unique()))
# Out:
# 0
# 37
# ['andaman and nicobar islands', 'andhra pradesh', 'arunachal pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'dadra and nagar haveli and daman and diu', 'delhi', 'goa', 'gujarat', 'haryana', 'himachal pradesh', 'jammu and kashmir', 'jharkhand', 'karnataka', 'kerala', 'ladakh', 'lakshadweep', 'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil nadu', 'telangana', 'tripura', 'unknown', 'uttar pradesh', 'uttarakhand', 'west bengal']

# %% [markdown]
# ## String Columns

# %%
# Check number of unique values for each column
for col in string_columns:
    print(f"{col:<20} {amazon_sales[col].nunique()} unique values")
# Out:
# order_id             120378 unique values
# style                1377 unique values
# sku                  7195 unique values
# asin                 7190 unique values
# ship_city            7298 unique values
# promotion_ids        5787 unique values
# ship_postal_code     9460 unique values

# %% [markdown]
# Next, we will:
#
# - Check style, sku, and asin column values for unexpected characters.
# - Check tail end of value_counts sample for bogus values.

# %%
# Check for unusual values in string columns
for col in ['style', 'asin', 'sku']:
    print(amazon_sales[amazon_sales[col].str.contains(r'[^a-zA-Z0-9\s-]', na=True)], end="\n\n")

for col in ['style', 'asin', 'sku']:
    print(amazon_sales[col].value_counts().tail(10))
# Out:
# Empty DataFrame
# Columns: [index, order_id, date, status, fulfillment, sales_channel, ship_service_level, style, sku, category, size, asin, quantity, currency, amount, ship_city, ship_state_or_territory, ship_postal_code, ship_country, promotion_ids, b2b]
# Index: []
#
# [0 rows x 21 columns]
#
# Empty DataFrame
# Columns: [index, order_id, date, status, fulfillment, sales_channel, ship_service_level, style, sku, category, size, asin, quantity, currency, amount, ship_city, ship_state_or_territory, ship_postal_code, ship_country, promotion_ids, b2b]
# Index: []
#
# [0 rows x 21 columns]
#
# Empty DataFrame
# Columns: [index, order_id, date, status, fulfillment, sales_channel, ship_service_level, style, sku, category, size, asin, quantity, currency, amount, ship_city, ship_state_or_territory, ship_postal_code, ship_country, promotion_ids, b2b]
# Index: []
#
# [0 rows x 21 columns]
#
# style
# CH207      1
# J0115      1
# SAR140     1
# DPT052     1
# DPT041     1
# SAR182     1
# DPT032     1
# SET446     1
# JNE3450    1
# SET045     1
# Name: count, dtype: Int64
# asin
# B09J19DKYF    1
# B08C31B5JR    1
# B099NR72V2    1
# B09Y328YW6    1
# B09RKBLR2K    1
# B091GN6CZ1    1
# B09M6W44KD    1
# B085GBDW68    1
# B08PV1B9JY    1
# B07N81TFNY    1
# Name: count, dtype: Int64
# sku
# JNE3899-KR-A-S        1
# BTM003-XXXL           1
# SET432-KR-PP-XXL      1
# SET461-KR-NP-XS       1
# SET449-KR-NP-M        1
# J0152-DR-M            1
# J0085-TP-L            1
# SET022-KR-SP-A-XXL    1
# JNE3030-KR-S          1
# SET045-KR-NP-M        1
# Name: count, dtype: Int64

# %% [markdown]
# Looks good. Next up, postal codes still have a decimal digit from being float type. Let's fix that and check ship_city and postal code for unusual characters

# %%
# Fix postal code decimal place and check for unusual values
amazon_sales['ship_postal_code'] = amazon_sales['ship_postal_code'].str.replace('\.0$', '', regex=True)
display(amazon_sales[amazon_sales['ship_postal_code'].str.contains(r'[^0-9\s]', regex=True)])
display(amazon_sales[amazon_sales['ship_city'].str.contains(r'[^a-zA-Z\s]', regex=True)])
# Out:
#          index             order_id       date                        status  \
# 1871      1871  404-0566904-4825137 2022-04-29                       shipped
# 1872      1872  404-0566904-4825137 2022-04-29                       shipped
# 8752      8752  406-4003386-8768363 2022-04-25                       shipped
# 11215    11215  402-0107720-7057168 2022-04-23                       shipped
# 13252    13252  407-4532637-8415521 2022-04-22         cancelled or returned
# 15688    15688  404-9229894-8608305 2022-04-21                       shipped
# 16787    16787  402-4919636-4333150 2022-04-20  shipped - delivered to buyer
# 18351    18351  405-4927647-8064368 2022-04-19                       shipped
# 22930    22930  402-8628677-0457954 2022-04-16         cancelled or returned
# 24986    24986  406-4079063-8291520 2022-04-15         cancelled or returned
# 30379    30379  404-7506843-7913132 2022-04-12  shipped - delivered to buyer
# 37963    37963  407-3064376-9158743 2022-04-08         cancelled or returned
# 37964    37964  407-3064376-9158743 2022-04-08         cancelled or returned
# 60986    60986  171-3257610-9237139 2022-05-22  shipped - delivered to buyer
# 63040    63040  402-1049475-3611523 2022-05-20                       shipped
# 73675    73675  405-1356730-8598722 2022-05-11  shipped - delivered to buyer
# 73746    73746  407-4664354-2179554 2022-05-11                       shipped
# 73771    73771  406-7680604-5439529 2022-05-11                       shipped
# 73772    73772  406-7680604-5439529 2022-05-11                       shipped
# 73911    73911  405-3420451-5230744 2022-05-11         cancelled or returned
# 80011    80011  171-4552355-0255565 2022-05-07         cancelled or returned
# 80092    80092  403-2857451-7335536 2022-05-07                       shipped
# 80455    80455  171-4691098-8489159 2022-05-06  shipped - delivered to buyer
# 84008    84008  405-8605864-8021901 2022-05-04         cancelled or returned
# 84757    84757  402-8651786-0683548 2022-05-04                       shipped
# 104201  104201  403-3190636-2013146 2022-06-18  shipped - delivered to buyer
# 106498  106498  402-8673941-7883531 2022-06-16         cancelled or returned
# 124215  124215  405-0340492-2359532 2022-06-04         cancelled or returned
# 124357  124357  405-5884153-9925116 2022-06-04                       shipped
# 124358  124358  405-5884153-9925116 2022-06-04                       shipped
# 124359  124359  405-5884153-9925116 2022-06-04                       shipped
# 125385  125385  403-5172380-9787567 2022-06-03                       shipped
# 126620  126620  403-4249038-6582716 2022-06-02  shipped - delivered to buyer
#
#        fulfillment sales_channel ship_service_level     style  \
# 1871        amazon     amazon.in          expedited     J0301
# 1872        amazon     amazon.in          expedited   JNE3697
# 8752        amazon     amazon.in          expedited   JNE3376
# 11215       amazon     amazon.in          expedited     J0003
# 13252    easy ship     amazon.in           standard   JNE3405
# 15688       amazon     amazon.in          expedited   JNE3510
# 16787    easy ship     amazon.in           standard   JNE1233
# 18351       amazon     amazon.in          expedited     J0230
# 22930    easy ship     amazon.in           standard     J0003
# 24986       amazon     amazon.in          expedited   JNE3567
# 30379    easy ship     amazon.in           standard    SET350
# 37963    easy ship     amazon.in           standard   JNE3567
# 37964    easy ship     amazon.in           standard   JNE3405
# 60986    easy ship     amazon.in           standard   JNE3365
# 63040       amazon     amazon.in          expedited   JNE3739
# 73675    easy ship     amazon.in           standard    SET187
# 73746       amazon     amazon.in          expedited    SET374
# 73771       amazon     amazon.in          expedited  PJNE3607
# 73772       amazon     amazon.in          expedited  PJNE3368
# 73911       amazon     amazon.in          expedited    SET374
# 80011    easy ship     amazon.in           standard    SET324
# 80092       amazon     amazon.in          expedited   JNE3510
# 80455    easy ship     amazon.in           standard    SET183
# 84008    easy ship     amazon.in           standard   JNE1951
# 84757       amazon     amazon.in          expedited   JNE3690
# 104201   easy ship     amazon.in           standard     J0351
# 106498      amazon     amazon.in          expedited   JNE3734
# 124215      amazon     amazon.in          expedited   JNE3465
# 124357      amazon     amazon.in          expedited   JNE3697
# 124358      amazon     amazon.in          expedited    SET337
# 124359      amazon     amazon.in          expedited    SET154
# 125385      amazon     amazon.in          expedited   JNE3366
# 126620   easy ship     amazon.in           standard   JNE3797
#
#                              sku       category  ...        asin quantity  \
# 1871                  J0301-TP-L            top  ...  B099S6795L        1
# 1872                JNE3697-KR-L          kurta  ...  B09811Y7WM        1
# 8752                JNE3376-KR-M          kurta  ...  B082W7HW86        1
# 11215                J0003-SET-S            set  ...  B0894X27FC        1
# 13252               JNE3405-KR-S          kurta  ...  B081WX4G4Q        0
# 15688               JNE3510-KR-M          kurta  ...  B08WPR5MCB        1
# 16787   JNE1233-BLUE-KR-031-XXXL          kurta  ...  B07GPGP46N        1
# 18351               J0230-SKD-XS            set  ...  B08XNHXSFZ        1
# 22930                J0003-SET-S            set  ...  B0894X27FC        1
# 24986             JNE3567-KR-XXL          kurta  ...  B08KRYCC8J        1
# 30379             SET350-KR-NP-L            set  ...  B09RKDXRZK        1
# 37963               JNE3567-KR-M          kurta  ...  B08KRXV1QR        0
# 37964               JNE3405-KR-S          kurta  ...  B081WX4G4Q        0
# 60986        JNE3365-KR-1052-A-L          kurta  ...  B07WP5GQKV        1
# 63040             JNE3739-KR-XXL          kurta  ...  B099NK7Y5P        1
# 73675            SET187-KR-DH-XL            set  ...  B08B415N6S        1
# 73746             SET374-KR-NP-M            set  ...  B09NDKJKPN        1
# 73771            PJNE3607-KR-4XL          kurta  ...  B09PY7YGTC        1
# 73772            PJNE3368-KR-4XL          kurta  ...  B09PY691XK        1
# 73911             SET374-KR-NP-M            set  ...  B09NDKJKPN        0
# 80011            SET324-KR-NP-XL            set  ...  B09NQ4QS13        1
# 80092               JNE3510-KR-S          kurta  ...  B08WPTJBBD        1
# 80455             SET183-KR-DH-M            set  ...  B08B3Z2YY3        1
# 84008         JNE1951-KR-155-XXL          kurta  ...  B07141LX6Q        1
# 84757              JNE3690-TU-XL            top  ...  B094FKN153        1
# 104201               J0351-SET-S            set  ...  B09CT88XNF        1
# 106498             JNE3734-KR-XL          kurta  ...  B09RKDBVR6        0
# 124215              JNE3465-KR-L          kurta  ...  B08BFLKNGJ        1
# 124357              JNE3697-KR-L          kurta  ...  B09811Y7WM        1
# 124358            SET337-KR-NP-L            set  ...  B09KXY99M3        1
# 124359            SET154-KR-NP-L            set  ...  B082PXXBXM        1
# 125385         JNE3366-KR-1053-L          kurta  ...  B07T65WM8Q        1
# 126620              JNE3797-KR-M  western dress  ...  B09SDY8DCT        1
#
#         currency  amount  ship_city ship_state_or_territory ship_postal_code  \
# 1871         INR   493.0    unknown                 unknown          unknown
# 1872         INR   458.0    unknown                 unknown          unknown
# 8752         INR   432.0    unknown                 unknown          unknown
# 11215        INR   654.0    unknown                 unknown          unknown
# 13252        INR   380.0    unknown                 unknown          unknown
# 15688        INR   442.0    unknown                 unknown          unknown
# 16787        INR   376.0    unknown                 unknown          unknown
# 18351        INR  1112.0    unknown                 unknown          unknown
# 22930        INR   654.0    unknown                 unknown          unknown
# 24986        INR   399.0    unknown                 unknown          unknown
# 30379        INR  1299.0    unknown                 unknown          unknown
# 37963        INR   380.0    unknown                 unknown          unknown
# 37964        INR   380.0    unknown                 unknown          unknown
# 60986        INR   376.0    unknown                 unknown          unknown
# 63040        INR   459.0    unknown                 unknown          unknown
# 73675        INR   699.0    unknown                 unknown          unknown
# 73746        INR   666.0    unknown                 unknown          unknown
# 73771        INR   869.0    unknown                 unknown          unknown
# 73772        INR   869.0    unknown                 unknown          unknown
# 73911        NaN     NaN    unknown                 unknown          unknown
# 80011        INR   607.0    unknown                 unknown          unknown
# 80092        INR   467.0    unknown                 unknown          unknown
# 80455        INR   759.0    unknown                 unknown          unknown
# 84008        INR   368.0    unknown                 unknown          unknown
# 84757        INR   487.0    unknown                 unknown          unknown
# 104201       INR   792.0    unknown                 unknown          unknown
# 106498       NaN     NaN    unknown                 unknown          unknown
# 124215       INR   491.0    unknown                 unknown          unknown
# 124357       INR   486.0    unknown                 unknown          unknown
# 124358       INR   874.0    unknown                 unknown          unknown
# 124359       INR   832.0    unknown                 unknown          unknown
# 125385       INR   376.0    unknown                 unknown          unknown
# 126620       INR   735.0    unknown                 unknown          unknown
#
#        ship_country                                      promotion_ids    b2b
# 1871             IN       in core free shipping 2015/04/08 23-48-5-108  False
# 1872             IN       in core free shipping 2015/04/08 23-48-5-108  False
# 8752             IN                                               <NA>  False
# 11215            IN       in core free shipping 2015/04/08 23-48-5-108  False
# 13252            IN                                               <NA>  False
# 15688            IN       in core free shipping 2015/04/08 23-48-5-108  False
# 16787            IN  amazon plcc free-financing universal merchant ...  False
# 18351            IN       in core free shipping 2015/04/08 23-48-5-108  False
# 22930            IN  amazon plcc free-financing universal merchant ...  False
# 24986            IN                                               <NA>  False
# 30379            IN  amazon plcc free-financing universal merchant ...  False
# 37963            IN                                               <NA>  False
# 37964            IN                                               <NA>  False
# 60986            IN  amazon plcc free-financing universal merchant ...  False
# 63040            IN       in core free shipping 2015/04/08 23-48-5-108  False
# 73675            IN  amazon plcc free-financing universal merchant ...  False
# 73746            IN       in core free shipping 2015/04/08 23-48-5-108  False
# 73771            IN       in core free shipping 2015/04/08 23-48-5-108  False
# 73772            IN       in core free shipping 2015/04/08 23-48-5-108  False
# 73911            IN                                               <NA>  False
# 80011            IN  amazon plcc free-financing universal merchant ...  False
# 80092            IN       in core free shipping 2015/04/08 23-48-5-108  False
# 80455            IN  amazon plcc free-financing universal merchant ...  False
# 84008            IN  amazon plcc free-financing universal merchant ...  False
# 84757            IN                                               <NA>  False
# 104201           IN  amazon plcc free-financing universal merchant ...  False
# 106498           IN       in core free shipping 2015/04/08 23-48-5-108  False
# 124215           IN                                               <NA>  False
# 124357           IN       in core free shipping 2015/04/08 23-48-5-108  False
# 124358           IN       in core free shipping 2015/04/08 23-48-5-108  False
# 124359           IN       in core free shipping 2015/04/08 23-48-5-108  False
# 125385           IN       in core free shipping 2015/04/08 23-48-5-108  False
# 126620           IN  amazon plcc free-financing universal merchant ...  False
#
# [33 rows x 21 columns]
#          index             order_id       date                        status  \
# 12          12  405-5513694-8146768 2022-04-30  shipped - delivered to buyer
# 122        122  406-8961316-8137943 2022-04-30  shipped - delivered to buyer
# 123        123  406-8961316-8137943 2022-04-30  shipped - delivered to buyer
# 155        155  402-8078642-8565124 2022-04-30         cancelled or returned
# 288        288  405-3441326-1516368 2022-04-30                       shipped
# ...        ...                  ...        ...                           ...
# 128770  128770  403-0380725-0352329 2022-06-01                       shipped
# 128855  128855  402-1958677-2521967 2022-06-01         cancelled or returned
# 128946  128946  404-4165392-8631530 2022-05-31                       shipped
# 128965  128965  408-5154281-4593912 2022-05-31         cancelled or returned
# 128966  128966  406-9812666-2474761 2022-05-31                       shipped
#
#        fulfillment sales_channel ship_service_level    style              sku  \
# 12       easy ship     amazon.in           standard  JNE3405    JNE3405-KR-XS
# 122      easy ship     amazon.in           standard   SET324   SET324-KR-NP-S
# 123      easy ship     amazon.in           standard   SET332   SET332-KR-PP-S
# 155         amazon     amazon.in          expedited  JNE3887    JNE3887-KR-XL
# 288         amazon     amazon.in          expedited    J0118    J0118-TP-XXXL
# ...            ...           ...                ...      ...              ...
# 128770      amazon     amazon.in          expedited  JNE3703    JNE3703-KR-XL
# 128855   easy ship     amazon.in           standard  JNE3568     JNE3568-KR-M
# 128946      amazon     amazon.in          expedited  JNE3560     JNE3560-KR-M
# 128965      amazon     amazon.in          expedited    J0119    J0119-TP-XXXL
# 128966      amazon     amazon.in          expedited   SET224  SET224-KR-NP-XS
#
#        category  ...        asin quantity  currency  amount  \
# 12        kurta  ...  B081XCMYXJ        1       INR   399.0
# 122         set  ...  B09NQ4CZ65        1       INR   597.0
# 123         set  ...  B09NQ33VW2        1       INR   549.0
# 155       kurta  ...  B09TZVXQ1J        0       NaN     NaN
# 288         top  ...  B08N43MK22        1       INR   518.0
# ...         ...  ...         ...      ...       ...     ...
# 128770    kurta  ...  B099NNYQ1K        1       INR   292.0
# 128855    kurta  ...  B08KRZRSCL        0       NaN     NaN
# 128946    kurta  ...  B08PCVMF6R        1       INR   544.0
# 128965      top  ...  B08RYPRVPV        1       INR   574.0
# 128966      set  ...  B08MXDBRK1        1       INR  1132.0
#
#                         ship_city ship_state_or_territory ship_postal_code  \
# 12                      amravati.             maharashtra           444606
# 122          guwahati, kamrup (m)                   assam           781014
# 123          guwahati, kamrup (m)                   assam           781014
# 155                        puri-2                  odisha           752002
# 288                kolkata 700034             west bengal           700034
# ...                           ...                     ...              ...
# 128770           new delhi 110032                   delhi           110032
# 128855           cherukunnu (p.o)                  kerala           670301
# 128946  gulabpura, distt bhilwara               rajasthan           311021
# 128965      prayagraj (allahabad)           uttar pradesh           211007
# 128966             chennai 600042              tamil nadu           600042
#
#        ship_country                                      promotion_ids    b2b
# 12               IN  amazon plcc free-financing universal merchant ...  False
# 122              IN  amazon plcc free-financing universal merchant ...  False
# 123              IN  amazon plcc free-financing universal merchant ...  False
# 155              IN                                               <NA>  False
# 288              IN       in core free shipping 2015/04/08 23-48-5-108  False
# ...             ...                                                ...    ...
# 128770           IN                                               <NA>  False
# 128855           IN                                               <NA>  False
# 128946           IN       in core free shipping 2015/04/08 23-48-5-108  False
# 128965           IN                                               <NA>  False
# 128966           IN                                               <NA>  False
#
# [2204 rows x 21 columns]

# %% [markdown]
# Postal code looks good. Ship city needs advanced querying to fix and we will address it in sql. Let's check promotion_ids

# %%
# Inspect promotion_ids
pd.set_option('display.max_colwidth', None)
display(amazon_sales[
    amazon_sales['promotion_ids']
    .str.contains('amazon', case=False, na=False)]
    ['promotion_ids'].head(1))
# Out:
# 1    amazon plcc free-financing universal merchant aat-wnktbo3k27ejc,amazon plcc free-financing universal merchant aat-qx3uccjeskpa2,amazon plcc free-financing universal merchant aat-5qq7biyyqedn2,amazon plcc free-financing universal merchant aat-dsj2qrxxwxvmq,amazon plcc free-financing universal merchant aat-cxjhmc2yjuk76,amazon plcc free-financing universal merchant aat-cc4favtyr4x7c,amazon plcc free-financing universal merchant aat-xxrcw6nzepzi4,amazon plcc free-financing universal merchant aat-cxnslnbrofdw4,amazon plcc free-financing universal merchant aat-r7gxnzwistrfa,amazon plcc free-financing universal merchant aat-wsjldn3x7kemo,amazon plcc free-financing universal merchant aat-vl6fgqvgqvxus,amazon plcc free-financing universal merchant aat-eokpwfwyw7y6i,amazon plcc free-financing universal merchant aat-zyl5upunw6t62,amazon plcc free-financing universal merchant aat-xvpicchrwdcai,amazon plcc free-financing universal merchant aat-etxq3xxwmrxbg,amazon plcc free-financing universal merchant aat-7x3xctyg64vbe,amazon plcc free-financing universal merchant aat-7chgd3wts3mhm,amazon plcc free-financing universal merchant aat-26zdknme27x42,amazon plcc free-financing universal merchant aat-4zf5kn6e4ljk4,amazon plcc free-financing universal merchant aat-7rcxikuax7ddy,amazon plcc free-financing universal merchant aat-brszz45h6mhao,amazon plcc free-financing universal merchant aat-mklxoozwql7go,amazon plcc free-financing universal merchant aat-cb7unxexgijtc,amazon plcc free-financing universal merchant #mp-gzasho-1593152694811,amazon plcc free-financing universal merchant aat-wlba4gz52eah4
# Name: promotion_ids, dtype: string
# Empty DataFrame
# Columns: [index, order_id, date, status, fulfillment, sales_channel, ship_service_level, style, sku, category, size, asin, quantity, currency, amount, ship_city, ship_state_or_territory, ship_postal_code, ship_country, promotion_ids, b2b]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# It looks like this column is filled incorrectly. For example, this order has a single item, but it has more than 10
# promotional codes applied in a repetitive fashion. Since we can't reliably differentiate promotional codes,
# we will focus our analysis on whether there is a promotion. i.e. we will convert to boolean

# %%
# Before we convert. Any promotion ids with normal string length?
display(amazon_sales[amazon_sales['promotion_ids'].str.len() < 10])

# Convert to boolean
amazon_sales['promotion_ids'] = amazon_sales['promotion_ids'].notna()

# %% [markdown]
# ## Numerical Columns

# %%
# Check number of null entries and entries with 0 value for amount and quantity
numeric_columns = ["quantity", "amount"]
print(f"Count of null entries:\n{amazon_sales[numeric_columns].isna().sum()}\n")
print(f"Quantity = 0: {(amazon_sales['quantity'] == 0).sum():>8}")
print(f"Amount = 0: {(amazon_sales['amount'] == 0).sum():>10}\n")


print(amazon_sales[numeric_columns].describe())
# Out:
# Count of null entries:
# quantity       0
# amount      7791
# dtype: int64
#
# Quantity = 0:    12803
# Amount = 0:       2343
#
#             quantity         amount
# count  128968.000000  121177.000000
# mean        0.904457     648.555776
# std         0.313321     281.209851
# min         0.000000       0.000000
# 25%         1.000000     449.000000
# 50%         1.000000     605.000000
# 75%         1.000000     788.000000
# max        15.000000    5584.000000

# %%
# How many of the orders missing payment infor are cancelled?

amazon_sales[
    (amazon_sales['quantity'] == 0) |
    (amazon_sales['quantity'].isna()) |
    (amazon_sales['amount'] == 0) |
    (amazon_sales['amount'].isna()) 
]['status'].value_counts()
# Out:
# status
# cancelled or returned           13000
# shipped                          1518
# shipped - delivered to buyer      724
# shipped - picked up                28
# Name: count, dtype: int64

# %% [markdown]
# While the majority of the orders missing payment info have cancelled/returned status, I would like to recover this information to analyze missed revenue opporunity. We will
# recover this information in SQL.

# %%
# Also ooks like all orders made through non-amazon sales channel are missing currency and amount.
print(amazon_sales['sales_channel'].value_counts(), "\n")
print(amazon_sales[amazon_sales['sales_channel'] == "non-amazon"].isna().sum())
# Out:
# sales_channel
# amazon.in     128844
# non-amazon       124
# Name: count, dtype: int64
#
# index                        0
# order_id                     0
# date                         0
# status                       0
# fulfillment                  0
# sales_channel                0
# ship_service_level           0
# style                        0
# sku                          0
# category                     0
# size                         0
# asin                         0
# quantity                     0
# currency                   124
# amount                     124
# ship_city                    0
# ship_state_or_territory      0
# ship_postal_code             0
# ship_country                 0
# promotion_ids                0
# b2b                          0
# dtype: int64

# %%
# final check on datatypes and columns we modiefied before exporting to sql
amazon_sales.info()
columns_to_inspect = ['status', 'fulfillment', 'ship_state_or_territory', 'ship_country', 'promotion_ids']
for col in columns_to_inspect:
    print("\n", amazon_sales[col].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128968 entries, 0 to 128974
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   index                    128968 non-null  int64
#  1   order_id                 128968 non-null  string
#  2   date                     128968 non-null  datetime64[ns]
#  3   status                   128968 non-null  object
#  4   fulfillment              128968 non-null  object
#  5   sales_channel            128968 non-null  object
#  6   ship_service_level       128968 non-null  object
#  7   style                    128968 non-null  string
#  8   sku                      128968 non-null  string
#  9   category                 128968 non-null  object
#  10  size                     128968 non-null  object
#  11  asin                     128968 non-null  string
#  12  quantity                 128968 non-null  int64
#  13  currency                 121177 non-null  object
#  14  amount                   121177 non-null  float64
#  15  ship_city                128968 non-null  string
#  16  ship_state_or_territory  128968 non-null  object
#  17  ship_postal_code         128968 non-null  string
#  18  ship_country             128968 non-null  object
#  19  promotion_ids            128968 non-null  bool
#  20  b2b                      128968 non-null  bool
# dtypes: bool(2), datetime64[ns](1), float64(1), int64(2), object(9), string(6)
# memory usage: 19.9+ MB
#
#  status
# shipped                         77603
# shipped - delivered to buyer    28769
# cancelled or returned           21588
# shipped - picked up               973
# shipped - out for delivery         35
# Name: count, dtype: int64
#
#  fulfillment
# amazon       89691
# easy ship    39277
# Name: count, dtype: int64
#
#  ship_state_or_territory
# maharashtra                                 22259
# karnataka                                   17325
# tamil nadu                                  11482
# telangana                                   11330
# uttar pradesh                               10637
# delhi                                        7048
# kerala                                       6584
# west bengal                                  5962
# andhra pradesh                               5430
# gujarat                                      4489
# haryana                                      4415
# rajasthan                                    2718
# madhya pradesh                               2529
# odisha                                       2139
# bihar                                        2114
# punjab                                       1918
# assam                                        1663
# uttarakhand                                  1553
# jharkhand                                    1456
# goa                                          1137
# chhattisgarh                                  909
# himachal pradesh                              788
# jammu and kashmir                             702
# puducherry                                    351
# chandigarh                                    333
# manipur                                       316
# andaman and nicobar islands                   257
# meghalaya                                     207
# sikkim                                        205
# nagaland                                      187
# tripura                                       151
# arunachal pradesh                             147
# mizoram                                        76
# dadra and nagar haveli and daman and diu       70
# ladakh                                         43
# unknown                                        34
# lakshadweep                                     4
# Name: count, dtype: int64
#
#  ship_country
# IN    128968
# Name: count, dtype: int64
#
#  promotion_ids
# True     79818
# False    49150
# Name: count, dtype: int64

# %%
# Write to csv file
timestamp = pd.Timestamp.now().strftime('%Y%m%d_%H%M%S')
amazon_sales.to_csv(f'data/amazon_sales_cleaned_{timestamp}.csv', index=False)
